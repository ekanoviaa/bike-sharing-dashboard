# %% [markdown]
# # Proyek Analisis Data: Bike-Sharing-Dataset
# - **Nama:** Eka Novia Ai'zatul Ulya
# - **Email:** cdcc180d6x2440@student.devacademy.id
# - **ID Dicoding:** eka_novia_ai'zatul_ulya__VKOX

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana perbedaan jumlah rata-rata penyewaan sepeda per jam antara hari kerja (workingday) dan akhir pekan (weekend) pada jam sibuk (07:00-09:00 dan 17:00-19:00) selama tahun 2012?
# 1. Specific (Spesifik) Pertanyaan ini sangat fokus. Ia tidak hanya menanyakan "kapan orang bersepeda", tetapi secara spesifik membandingkan dua jenis hari (kerja vs akhir pekan) pada interval jam tertentu (jam sibuk pagi dan sore).
# 2. Measurable (Terukur): Sangat terukur menggunakan metrik rata-rata hitung dari kolom cnt (total penyewaan) dan dikelompokkan berdasarkan kolom hr (jam).
# 3. Action-Oriented (Berorientasi Aksi): Hasil analisis ini memberikan instruksi logistik yang jelas. Jika pada jam sibuk hari kerja terjadi lonjakan, tim operasional harus melakukan rebalancing sepeda (memindahkan sepeda ke stasiun yang kosong) sebelum pukul 07:00 pagi.
# 4. Relevant (Relevan): Relevan dengan efisiensi operasional. Mengetahui perbedaan pola membantu manajemen mengalokasikan staf lapangan dengan lebih efektif antara hari kerja dan akhir pekan.
# 5. Time-bound (Terikat Waktu): Jelas dibatasi pada rentang waktu tahun 2012.
#
#
# - **Pertanyaan 2:** Sejauh mana pengaruh suhu ekstrem (temp > 30°C) terhadap total penyewaan harian oleh pengguna kasual dibandingkan pengguna terdaftar pada musim panas (Summer) tahun 2011 dan 2012?
# 1. Specific (Spesifik): Pertanyaan ini tidak hanya menanyakan "kapan orang bersepeda", tetapi secara spesifik membandingkan dua jenis hari (kerja vs akhir pekan) pada interval jam tertentu (jam sibuk pagi dan sore).
# 2. Measurable (Terukur): Sangat terukur menggunakan metrik rata-rata hitung dari kolom cnt (total penyewaan) dan dikelompokkan berdasarkan kolom hr (jam).
# 3. Action-Oriented (Berorientasi Aksi): Hasil analisis ini memberikan instruksi logistik yang jelas. Jika pada jam sibuk hari kerja terjadi lonjakan, tim operasional harus melakukan rebalancing sepeda (memindahkan sepeda ke stasiun yang kosong) sebelum pukul 07:00 pagi.
# 4. Relevant (Relevan): Relevan dengan efisiensi operasional. Mengetahui perbedaan pola membantu manajemen mengalokasikan staf lapangan dengan lebih efektif antara hari kerja dan akhir pekan.
# 5. Time-bound (Terikat Waktu): rentang waktu jelas yaitu tahun 2012.

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df Bike Sharing Dataset

# %%
day_df = pd.read_csv('day.csv')
hour_df = pd.read_csv('hour.csv')

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset day.csv memiliki 731 baris yang merepresentasikan data harian selama 2 tahun (2011-2012). Ini digunakan untuk melihat tren jangka panjang dan pengaruh musim.
# - Dataset hour.csv memiliki 17.379 baris yang mencatat data per jam. Dataset ini adalah kunci untuk memahami perilaku pengguna pada jam-jam spesifik (seperti jam sibuk pagi vs sore).
# - Kedua dataset memiliki fitur yang kaya, mulai dari kondisi cuaca (suhu, kelembapan) hingga tipe hari (hari libur, hari kerja).

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying Bike Sharing Dataset problem

# %%
# Cek struktur data dan tipe data
print(day_df.info())

# Cek apakah ada nilai yang kosong (missing values)
print("\nMissing values pada day_df:\n", day_df.isna().sum())

# Cek apakah ada data duplikat
print("\nJumlah duplikasi pada day_df:", day_df.duplicated().sum())

# Cek statistik deskriptif
print("\nDeskripsi Statistik:\n", day_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None
#
# Missing values pada day_df:
#  instant       0
# ...

# %% [markdown]
# **Steps to Take:**
# -  Kesalahan Tipe Data: Kolom dteday harus diubah dari object menjadi datetime.
# - Keterbacaan Kategorikal: Nilai angka pada season, yr, dan weathersit perlu diubah ke label deskriptif agar visualisasi mudah dipahami.
# - Outlier/Inaccurate Value: Terdapat nilai hum (kelembapan) yang bernilai 0 pada day_df, yang tidak mungkin secara alami di Washington D.C.

# %% [markdown]
# **Insight:** (Opsional)
# - Data bersih dari missing values (0 null), yang menandakan kualitas perekaman data oleh sistem Capital Bikeshare sangat baik.
# - Tidak ditemukan data duplikat, sehingga tidak perlu dilakukan pembersihan baris ganda.
# - Beberapa variabel seperti temp dan hum sudah dalam bentuk ternormalisasi (0 hingga 1), sehingga untuk analisis interpretatif, kita perlu memahami skala aslinya (misal: suhu maksimal 41°C).

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing Bike Sharing Dataset problem

# %%
# Load data
day_df = pd.read_csv('day.csv')
hour_df = pd.read_csv('hour.csv')

# Mengubah tipe data dteday ke datetime
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# Handling Inaccurate Value (Kelembapan 0 diubah ke rata-rata)
day_df['hum'] = day_df['hum'].replace(0, day_df['hum'].mean())

# Mapping label kategorikal agar lebih informatif
day_df['season'] = day_df['season'].map({1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})
day_df['yr'] = day_df['yr'].map({0: '2011', 1: '2012'})
day_df['weathersit'] = day_df['weathersit'].map({
    1: 'Clear', 2: 'Misty', 3: 'Light Rain/Snow', 4: 'Heavy Rain/Snow'
})

# Menampilkan hasil cleaning
day_df.head()
# Out:
#    instant     dteday  season    yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01  Spring  2011     1        0        6           0
# 1        2 2011-01-02  Spring  2011     1        0        0           0
# 2        3 2011-01-03  Spring  2011     1        0        1           1
# 3        4 2011-01-04  Spring  2011     1        0        2           1
# 4        5 2011-01-05  Spring  2011     1        0        3           1
#
#   weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0      Misty  0.344167  0.363625  0.805833   0.160446     331         654
# 1      Misty  0.363478  0.353739  0.696087   0.248539     131         670
# 2      Clear  0.196364  0.189405  0.437273   0.248309     120        1229
# 3      Clear  0.200000  0.212122  0.590435   0.160296     108        1454
# 4      Clear  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset lebih mudah dipahami
# - Normalisasi tipe data tanggal memungkinkan kita melakukan filter berdasarkan rentang waktu spesifik (seperti hanya tahun 2012) tanpa kesulitan teknis.
# Penanganan nilai hum yang 0 dengan metode mean imputation menjaga distribusi data tetap stabil tanpa menghilangkan informasi penting dari baris tersebut

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# EDA Univariate: Melihat statistik deskriptif data numerik (Tabel)
print("--- Statistik Deskriptif Variabel Numerik ---")
display(day_df[['temp', 'hum', 'windspeed', 'cnt']].describe())

# EDA Kategorikal: Melihat rata-rata penyewaan berdasarkan kondisi cuaca (Tabel)
print("\n--- Rata-rata Penyewaan berdasarkan Kondisi Cuaca ---")
# weathersit: 1=Clear, 2=Misty, 3=Light Rain/Snow
display(day_df.groupby('weathersit')['cnt'].mean().reset_index())

# EDA Kategorikal: Melihat rata-rata penyewaan per jam (Tabel)
print("\n--- Rata-rata Penyewaan per Jam (5 Baris Pertama) ---")
hourly_stats = hour_df.groupby('hr')['cnt'].mean().reset_index()
display(hourly_stats.head())

# EDA Multivariate: Melihat korelasi antar variabel (Tabel)
print("\n--- Matriks Korelasi Variabel Numerik ---")
display(day_df[['temp', 'atemp', 'hum', 'windspeed', 'cnt']].corr())

print("\n--- Analisis Khusus Pertanyaan Bisnis ---")
hourly_workingday = hour_df.groupby(['workingday', 'hr'])['cnt'].mean().reset_index()

summer_df = day_df[day_df['season'] == 'Summer'].copy()
summer_df['temp_celcius'] = summer_df['temp'] * 41

print("Korelasi Suhu dengan Casual:", summer_df['temp_celcius'].corr(summer_df['casual']))
print("Korelasi Suhu dengan Registered:", summer_df['temp_celcius'].corr(summer_df['registered']))
# Out:
# --- Statistik Deskriptif Variabel Numerik ---
#              temp         hum   windspeed          cnt
# count  731.000000  731.000000  731.000000   731.000000
# mean     0.495385    0.628753    0.190486  4504.348837
# std      0.183051    0.140518    0.077498  1937.211452
# min      0.059130    0.187917    0.022392    22.000000
# 25%      0.337083    0.521041    0.134950  3152.000000
# 50%      0.498333    0.627500    0.180975  4548.000000
# 75%      0.655417    0.730209    0.233214  5956.000000
# max      0.861667    0.972500    0.507463  8714.000000
# --- Rata-rata Penyewaan berdasarkan Kondisi Cuaca ---
#         weathersit          cnt
# 0            Clear  4876.786177
# 1  Light Rain/Snow  1803.285714
# 2            Misty  4035.862348
# --- Rata-rata Penyewaan per Jam (5 Baris Pertama) ---
#    hr        cnt
# 0   0  53.898072
# 1   1  33.375691
# 2   2  22.869930
# 3   3  11.727403
# 4   4   6.352941
# --- Matriks Korelasi Variabel Numerik ---
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Pertanyaan 1:
# Terdapat perbedaan pola aktivitas yang kontras; pada hari kerja penyewaan memuncak di jam sibuk pagi dan sore, sedangkan pada akhir pekan penggunaan meningkat stabil di siang hari untuk keperluan rekreasi.
# - Pertanyaan 2:
# Suhu panas ekstrem (>30°C) tidak menurunkan loyalitas pengguna Registered yang bahkan mencapai sekitar 3x lipat lebih tinggi karena kebutuhan transportasi rutin, sementara pengguna Casual sangat dipengaruhi oleh cuaca dan cenderung mengurangi aktivitas bersepeda saat suhu terlalu panas

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
hour_2012 = hour_df[hour_df['yr'] == 1].copy()
hour_2012['day_type'] = hour_2012['workingday'].map({
    1: 'Hari Kerja',
    0: 'Akhir Pekan/Libur'
})

# Menghitung rata-rata penyewaan per jam berdasarkan hari
hourly_trend = hour_2012.groupby(['day_type', 'hr'])['cnt'].mean().reset_index()

# Visualisasi
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=hourly_trend,
    x='hr',
    y='cnt',
    hue='day_type',
    marker='o',
    palette={'Hari Kerja': 'red', 'Akhir Pekan/Libur': 'blue'} # Mengunci warna agar tidak tertukar
)

plt.axvspan(7, 9, color='green', alpha=0.15, label='Jam Sibuk Pagi')
plt.axvspan(17, 19, color='orange', alpha=0.15, label='Jam Sibuk Sore')

plt.title('Pola Penyewaan Sepeda: Hari Kerja vs Akhir Pekan (Tahun 2012)', fontsize=14)
plt.xlabel('Jam (00:00 - 23:00)')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.xticks(range(0, 24))
plt.grid(True, linestyle='--', alpha=0.5)

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Filter data musim panas (Summer) dan suhu ekstrem (>30°C)
hot_summer_days = summer_df[summer_df['temp_celcius'] > 30]

# Menghitung rata-rata penyewaan untuk masing-masing tipe pengguna
mean_rentals = hot_summer_days[['casual', 'registered']].mean().reset_index()
mean_rentals.columns = ['User_Type', 'Avg_Rentals']

# Visualisasi
plt.figure(figsize=(8, 6))
# Bagian yang diubah
sns.barplot(
    data=mean_rentals,
    x='User_Type',
    y='Avg_Rentals',
    hue='User_Type',
    palette='YlOrRd',
    legend=False
)

for index, row in mean_rentals.iterrows():
    plt.text(index, row.Avg_Rentals + 50, f'{int(row.Avg_Rentals)}', ha='center', va='bottom')

plt.title('Rata-rata Penyewaan saat Suhu Ekstrem (>30°C) di Musim Panas')
plt.xlabel('Tipe Pengguna')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Pertanyaan 1:
# Terdapat perbedaan pola aktivitas yang kontras; pada hari kerja penyewaan memuncak di jam sibuk pagi dan sore, sedangkan pada akhir pekan penggunaan meningkat stabil di siang hari untuk keperluan rekreasi.
# - Pertanyaan 2:
# Suhu panas ekstrem (>30°C) tidak menurunkan loyalitas pengguna Registered yang bahkan mencapai sekitar 3x lipat lebih tinggi karena kebutuhan transportasi rutin, sementara pengguna Casual sangat dipengaruhi oleh cuaca dan cenderung mengurangi aktivitas bersepeda saat suhu terlalu panas.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Analisis Korelasi Multivariate
# Melihat korelasi antara suhu, kelembapan, kecepatan angin, dan total penyewaan
plt.figure(figsize=(8, 6))
correlation_matrix = day_df[['temp', 'hum', 'windspeed', 'cnt']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriks Korelasi Faktor Lingkungan')
plt.show()

# %% [markdown]
# - **Conclusion pertanyaan 1:** Hasil analisis menunjukkan adanya perbedaan pola penggunaan sepeda yang cukup signifikan antara hari kerja dan akhir pekan. Pada hari kerja, penggunaan sepeda cenderung mengikuti jadwal aktivitas perkantoran, yang ditandai dengan peningkatan jumlah penyewaan secara tajam pada pukul 08.00 dan 17.00. Kondisi ini mengindikasikan bahwa sepeda dimanfaatkan sebagai sarana transportasi utama oleh para pekerja (komuter).Sebaliknya, pada akhir pekan, pola penggunaan sepeda terlihat lebih fleksibel dan tidak terikat waktu tertentu. Permintaan mulai meningkat secara bertahap sejak sekitar pukul 10.00 dan mencapai puncaknya pada siang hari. Hal ini menunjukkan bahwa pada hari libur, sepeda lebih banyak digunakan untuk keperluan rekreasi atau aktivitas santai
# - **Conclusion pertanyaan 2:**  Analisis terhadap variabel suhu menunjukkan perbedaan respons antara dua kelompok pengguna. Ketika suhu udara berada pada tingkat yang tinggi (di atas 30°C), pengguna Registered (pelanggan terdaftar) cenderung tetap menggunakan sepeda dengan tingkat penggunaan yang relatif stabil. Hal ini mengindikasikan adanya kebutuhan mobilitas yang bersifat rutin, sehingga mereka tetap menggunakan layanan meskipun kondisi cuaca kurang mendukung. Di sisi lain, pengguna Casual menunjukkan tingkat sensitivitas yang lebih tinggi terhadap suhu. Pada kondisi panas yang ekstrem, jumlah penyewaan dari kelompok ini mengalami penurunan yang cukup signifikan. Hal ini dapat dipahami karena bagi pengguna kasual, bersepeda lebih bersifat pilihan aktivitas santai yang dapat ditunda atau dibatalkan ketika kondisi lingkungan tidak nyaman.

# %% [markdown]
# **Rekomendasi Action Item:**
# - Mengalokasikan lebih banyak sepeda di lokasi dengan permintaan tinggi pada jam sibuk untuk memaksimalkan potensi pendapatan harian
# - Menawarkan paket langganan atau membership yang lebih menarik guna mempertahankan dan meningkatkan jumlah pengguna registered
# - Mengurangi biaya operasional dengan membatasi distribusi sepeda pada jam dan kondisi dengan permintaan rendah

# %%
day_df.to_csv("main_data.csv", index=False)
